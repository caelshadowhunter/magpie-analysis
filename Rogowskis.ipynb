# %%
# %matplotlib nbagg
# Out:
# C:\Users\Sav\Anaconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
from bdots import *
import os
os.getcwd()
# Out:
# 'C:\\Users\\Sav\\Documents\\GitHub\\magpie-analysis'

# %%
fig, ax=plt.subplots(figsize=(12,8))

r=Rogowskis("s0303_16")
r.truncate(cal=[10*10.4*3e9,-10.48*10.79*3e9])
r.integrate()
r.plot("I_Tot0", scale=1e-6, ax=ax, plotSep=True)
# Out:
# <img src="data:image/png;base64,...">
# s0303_16: using both Rogs
# Option to plot seperatly was invoked

# %%
#plt.close()

# %%
0.002*1e6
# Out:
# 2000.0

# %%
r.I2.max()<5e5
# Out:
# True
